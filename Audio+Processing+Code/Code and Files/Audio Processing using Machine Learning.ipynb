# %% [markdown]
# ## Project Name : Audio Processing using ML

# %% [markdown]
# ### In this project we will be understanding and extracting different features from audio files which help us in performing ML operations on these audio files.

# %% [markdown]
# ![pexels-photo-2579041.jpeg](attachment:pexels-photo-2579041.jpeg)

# %% [markdown]
# ### Time Line of the project :
# - Importing libraties and audio file
# - Understanding our audio file
# - Extracting Time Domain Audio Features
# - Fourier Transform and it's applications
# - Extracting Frequency Domain Audio Features

# %% [markdown]
# Installing Librosa library

# %%
! pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.3.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.61.2)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (4.16.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.1.1)
# Requirement already satisfied: packaging in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from lazy-loader>=0.1->librosa) (26.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from pooch>=1.0->librosa) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pooch>=1.0->librosa) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# WARNING: Ignoring invalid distribution -elery (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ttpx (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -elery (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ttpx (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -elery (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ttpx (c:\users\dell\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loading our Audio File

# %%
ipd.Audio('file_example_WAV_2MG.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Reading our file with Librosa library

# %%
music , sr = librosa.load('file_example_WAV_2MG.wav')
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\core\intervals.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
print("Shape of the audio file: ",music.shape)
print("Sample Rate of the audio file: ",sr)
# Out:
# Shape of the audio file:  (739329,)
# Sample Rate of the audio file:  22050

# %% [markdown]
# Duration of one sample in seconds

# %%
sample_duration = 1 / sr
print(f"Duration of one sample is {sample_duration:6f} seconds")
# Out:
# Duration of one sample is 0.000045 seconds

# %%
# total number of samples in audio file
tot_samples = len(music)
tot_samples
# Out:
# 739329

# %% [markdown]
# If we want to find out duration in seconds

# %%
duration = 1 / sr * tot_samples
print(f"Duration of whole audio is {duration} seconds")
# Out:
# Duration of whole audio is 33.52965986394558 seconds

# %% [markdown]
# Visualising audio signal in the time domain

# %%
plt.figure(figsize=(30, 10))

# waveplot ki jagah waveshow use karein
librosa.display.waveshow(music, sr=sr, alpha=0.5)

plt.ylim((-1, 1))
plt.title("Sample music")
plt.show()

# %% [markdown]
# ### Extracting Time Domain Audio Features

# %% [markdown]
# The different types of time domain features are:
# - Amplitude Envelope
# - Zero Crossing Rate
# - Root Mean Square Enerergy

# %% [markdown]
# ### Amplitude Envelope :

# %% [markdown]
# AE is the maximum value of all the samples in a frame

# %% [markdown]
# Calculating an Amplitude Envelope

# %%
FRAME_SIZE = 1024
HOP_LENGTH = 512  ### used for overlapping frames

def amplitude_envelope(signal, frame_size, hop_length):
    amplitude_envelope = []
    
    # calculate amplitude envelope for each frame
    for i in range(0, len(signal), hop_length): 
        amplitude_envelope_current_frame = max(signal[i:i+frame_size]) 
        amplitude_envelope.append(amplitude_envelope_current_frame)
    
    return np.array(amplitude_envelope)

# %%
AE_music = amplitude_envelope(music, FRAME_SIZE, HOP_LENGTH)

# %% [markdown]
# If we want to see how many frames have been produced

# %%
print("The total number of frames produced : ",len(AE_music))
# Out:
# The total number of frames produced :  1445

# %% [markdown]
# Visualising the AE

# %%
frames = range(len(AE_music))
t = librosa.frames_to_time(frames, hop_length=HOP_LENGTH)

plt.figure(figsize=(30, 10))

# waveplot -> waveshow with sr parameter
librosa.display.waveshow(music, sr=sr, alpha=0.5)

# Plot Amplitude Envelope line
plt.plot(t, AE_music, color="r")
plt.ylim((-1, 1))
plt.title("Sample music")
plt.show()

# %% [markdown]
# #### Applications of Amplitude Envelope :
# - Gives max amplitude values in a frame
# - Gives a rough idea of loudness
# - Used for music genre classification or onset detection

# %% [markdown]
# ### Zero Crossing Rate :

# %% [markdown]
# The is the rate at which a signal crosses the negative value to zero and then to a possitive value

# %%
ZCR_music = librosa.feature.zero_crossing_rate(music, frame_length=FRAME_SIZE, hop_length=HOP_LENGTH)[0]

# %%
frames = range(len(ZCR_music))
t = librosa.frames_to_time(frames, hop_length=HOP_LENGTH)

# %%
plt.figure(figsize=(30, 10))

plt.plot(t, ZCR_music, color="b")

# %% [markdown]
# #### Applications of Zero Crossing Rate :
# - Can be used for recursive v/s pitch sounds
# - To find out voice/unvoice decisions
# - Can be used to find out monophonic pitch

# %% [markdown]
# ### Root Mean Square Energy :

# %% [markdown]
# This is basically the root mean square of all the samples present in a frame

# %%
# y=music keyword argument pass karein
RMS_music = librosa.feature.rms(y=music, frame_length=FRAME_SIZE, hop_length=HOP_LENGTH)[0]

# %% [markdown]
# Visualising the RMS

# %%
frames = range(len(RMS_music))
t = librosa.frames_to_time(frames, hop_length=HOP_LENGTH)

plt.figure(figsize=(30, 10))

# waveplot ki jagah waveshow use karein
librosa.display.waveshow(music, sr=sr, alpha=0.5)

# Plot RMS Energy
plt.plot(t, RMS_music, color="r")
plt.ylim((-1, 1))
plt.title("Sample music - RMS Energy")
plt.show()

# %% [markdown]
# #### Applications of RMS Energy :
# - Gives RMS of all samples
# - This is also an indicator of loudness
# - Can be used for audio segementation or music genre classification

# %% [markdown]
# ### Fourier Transform and it's applications

# %% [markdown]
# Fourier Transform : A Fourier transform is a mathematical transform that decomposes functions depending on space or time into functions depending on spatial or temporal frequency, such as the expression of a musical chord in terms of the volumes and frequencies of its constituent notes

# %% [markdown]
# #### Applications of Fourier Transform :
# - Spectogram
# - Mel Frequency Cepstral Coefficients

# %% [markdown]
# #### Applying Fourier Transform i.e plotting frequency spectrum

# %%
fft_music = np.fft.fft(music)
len(fft_music)
# Out:
# 739329

# %%
def plot_magnitude_spectrum(signal, sr, title, f_ratio=1):
    fft_music = np.fft.fft(signal)
    fft_abs = np.absolute(fft_music)
    
    plt.figure(figsize=(18, 5))
    
    f = np.linspace(0, sr, len(fft_abs))
    f_bins = int(len(fft_abs)*f_ratio)  
    
    plt.plot(f[:f_bins], fft_abs[:f_bins])
    plt.xlabel('Frequency (Hz)')
    plt.title(title)

# %%
plot_magnitude_spectrum(music, sr, "Sample Music", 1)

# %% [markdown]
# #### Plotting a spectogram

# %%
### extracting short time fourier transform

FRAME_SIZE = 2048
HOP_SIZE = 512

ssft = librosa.stft(music, n_fft=FRAME_SIZE, hop_length=HOP_SIZE)

# %%
type(ssft[0][0])
# Out:
# numpy.complex64

# %% [markdown]
# We only want absolute values

# %%
ssft_abs = np.abs(ssft) ** 2
type(ssft_abs[0][0])
# Out:
# numpy.float32

# %% [markdown]
# Visualizing

# %%
def plot_spectrogram(Y, sr, hop_length, y_axis="linear"):
    plt.figure(figsize=(25, 10))
    librosa.display.specshow(Y, 
                             sr=sr, 
                             hop_length=hop_length, 
                             x_axis="time", 
                             y_axis=y_axis)
    plt.colorbar(format="%+2.f")

# %%
plot_spectrogram(ssft_abs, sr, HOP_SIZE)

# %% [markdown]
# This is because our audio file have low frequencies

# %%
# 1. STFT calculate karein
stft = librosa.stft(music, n_fft=FRAME_SIZE, hop_length=HOP_LENGTH)

# 2. Absolute magnitude nikaalein (Yeh 'sfft_abs' miss ho raha tha)
sfft_abs = np.abs(stft) ** 2  # Ya np.abs(stft)

# 3. Power ko dB (Log scale) me convert karein
sfft_abs_log = librosa.power_to_db(sfft_abs)

# 4. Custom plot function call karein ya direct librosa display use karein
plt.figure(figsize=(10, 4))
librosa.display.specshow(sfft_abs_log, sr=sr, hop_length=HOP_LENGTH, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Log-Frequency Power Spectrogram')
plt.show()

# %% [markdown]
# #### Calculating Mel Frequency Cepstral Coefficients

# %% [markdown]
# In sound processing, the mel-frequency cepstrum is a representation of the short-term power spectrum of a sound, based on a linear cosine transform of a log power spectrum on a nonlinear mel scale of frequency. Mel-frequency cepstral coefficients are coefficients that collectively make up an MFC.

# %% [markdown]
# Extracting MFCCs

# %%
mfccs = librosa.feature.mfcc(y=music, n_mfcc=13, sr=sr)

# %% [markdown]
# Extracting 1st and 2nd order MFCCs

# %%
delta_mfccs = librosa.feature.delta(mfccs)

# %%
delta2_mfccs = librosa.feature.delta(mfccs, order=2)

# %% [markdown]
# Visualizing MFCCs

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(mfccs, 
                         x_axis="time", 
                         sr=sr)
plt.colorbar(format="%+2.f")
plt.title('MFCCS')
plt.show()

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(delta_mfccs, 
                         x_axis="time", 
                         sr=sr)
plt.colorbar(format="%+2.f")
plt.title('1st order MFCCs')
plt.show()

# %%
plt.figure(figsize=(25, 10))
librosa.display.specshow(delta2_mfccs, 
                         x_axis="time", 
                         sr=sr)
plt.colorbar(format="%+2.f")
plt.title('2nd order MFCCs')
plt.show()

# %% [markdown]
# ### Advanced or Frequency Domain Audio Features

# %% [markdown]
# Different types of Frequency Domain Audio Features are :
# - Band Energy Ratio
# - Spectral Centroid

# %% [markdown]
# #### Band Energy Ratio :

# %% [markdown]
# Ratio of lower frequency bands to higher frequency bands

# %% [markdown]
# It is used in comparison of energy in lower/higher frequency bands and it also measures how dominat low frequencies are

# %% [markdown]
# Application of Band Energy Ratio :
# - Music and Speech determination
# - Music classification

# %% [markdown]
# #### Spectral Centroid :

# %% [markdown]
# The spectral centroid is a measure used in digital signal processing to characterise a spectrum. It indicates where the center of mass of the spectrum is located. Perceptually, it has a robust connection with the impression of brightness of a sound.

# %% [markdown]
# It is a measure of the brightness of the sound

# %% [markdown]
# Calculates the weighted mean of frequencies

# %% [markdown]
# Application of Spectral Centroid:
# - Music Classification
# - Audio Classification
